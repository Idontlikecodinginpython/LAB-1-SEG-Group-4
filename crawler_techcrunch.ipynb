# %%
# Task 1: Cài đặt và nạp các thư viện cần thiết
# !pip install requests beautifulsoup4 pandas

import os
import time
import hashlib
import sqlite3
import requests
import pandas as pd
from datetime import datetime
from collections import deque
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup

print("Import thư viện thành công!")
# Out:
# Requirement already satisfied: requests in c:\users\gamep\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\gamep\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pandas in c:\users\gamep\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gamep\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gamep\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gamep\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gamep\anaconda3\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gamep\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\gamep\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gamep\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gamep\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gamep\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gamep\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gamep\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Import thư viện thành công!

# %%
# Task 1: Cấu hình tham số dành riêng cho TechCrunch
TOPIC = "Technology"
SEED_URL = "https://techcrunch.com/"
ALLOWED_DOMAINS = ["techcrunch.com", "www.techcrunch.com"]

MAX_DEPTH = 3
MAX_PAGES = 40            # Giới hạn 30-40 trang cho mỗi notebook
REQUEST_TIMEOUT = 10      # Giây
CRAWL_DELAY = 1.0         # Giây (Crawl Politeness)
DB_PATH = "data/crawler_techcrunch.db"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

print("=== CRAWLER CONFIGURATION ===")
print(f"Topic          : {TOPIC}")
print(f"Seed URL       : {SEED_URL}")
print(f"Allowed Domains: {ALLOWED_DOMAINS}")
print(f"Max Depth      : {MAX_DEPTH} | Max Pages: {MAX_PAGES}")
print(f"Crawl Delay    : {CRAWL_DELAY}s")
# Out:
# === CRAWLER CONFIGURATION ===
# Topic          : Technology
# Seed URL       : https://techcrunch.com/
# Allowed Domains: ['techcrunch.com', 'www.techcrunch.com']
# Max Depth      : 3 | Max Pages: 40
# Crawl Delay    : 1.0s

# %%
# Task 2, 6, 7: URL Frontier sử dụng deque (BFS) và set visited
class URLFrontier:
    def __init__(self, max_depth=3):
        self.queue = deque()
        self.visited = set()
        self.max_depth = max_depth
        self.discovered_count = 0
        self.skipped_count = 0

    def add_url(self, url, depth):
        self.discovered_count += 1
        if depth > self.max_depth or url in self.visited:
            self.skipped_count += 1
            return False
        self.visited.add(url)
        self.queue.append((url, depth))
        return True

    def get_next(self):
        return self.queue.popleft() if self.queue else None

    def is_empty(self):
        return len(self.queue) == 0

frontier = URLFrontier(max_depth=MAX_DEPTH)
print("Đã khởi tạo URL Frontier.")
# Out:
# Đã khởi tạo URL Frontier.

# %%
# Duplicate Detection: Kiểm tra exact duplicate nội dung bằng băm SHA-256
class DuplicateDetector:
    def __init__(self):
        self.fingerprints = set()

    def is_duplicate(self, text_content):
        if not text_content:
            return True
        fp = hashlib.sha256(text_content.strip().encode("utf-8")).hexdigest()
        if fp in self.fingerprints:
            return True
        self.fingerprints.add(fp)
        return False

detector = DuplicateDetector()
print("Đã khởi tạo Duplicate Detector.")
# Out:
# Đã khởi tạo Duplicate Detector.

# %%
# Task 8: Thiết lập SQLite lưu trữ bảng 'pages' và 'links'
class Database:
    def __init__(self, db_path):
        os.makedirs(os.path.dirname(db_path), exist_ok=True)
        self.conn = sqlite3.connect(db_path)
        self.create_tables()

    def create_tables(self):
        cursor = self.conn.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS pages (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                url TEXT UNIQUE,
                domain TEXT,
                title TEXT,
                content TEXT,
                depth INTEGER,
                status_code INTEGER,
                crawled_at TEXT
            )
        ''')
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS links (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                source_url TEXT,
                target_url TEXT
            )
        ''')
        self.conn.commit()

    def insert_page(self, url, domain, title, content, depth, status_code, crawled_at):
        cursor = self.conn.cursor()
        cursor.execute('''
            INSERT OR IGNORE INTO pages (url, domain, title, content, depth, status_code, crawled_at)
            VALUES (?, ?, ?, ?, ?, ?, ?)
        ''', (url, domain, title, content, depth, status_code, crawled_at))
        self.conn.commit()

    def insert_link(self, source_url, target_url):
        cursor = self.conn.cursor()
        cursor.execute('''
            INSERT INTO links (source_url, target_url)
            VALUES (?, ?)
        ''', (source_url, target_url))
        self.conn.commit()

    def close(self):
        self.conn.close()

db = Database(DB_PATH)
print("Đã kết nối SQLite Database.")
# Out:
# Đã kết nối SQLite Database.

# %%
# Task 4 & Task 5: Bóc tách text, khử nhiễu (Noise Removal) và lọc URL
IGNORED_EXTENSIONS = (
    '.jpg', '.jpeg', '.png', '.gif', '.svg', '.webp', '.ico',
    '.css', '.js', '.zip', '.tar', '.gz', '.pdf', '.mp4', '.mp3'
)

TECH_KEYWORDS = [
    'tech', 'technology', 'ai', 'artificial intelligence', 'software', 
    'hardware', 'app', 'mobile', 'apple', 'google', 'microsoft', 'nvidia',
    'cybersecurity', 'gadget', 'robotics', 'cloud', 'data', 'crypto', 'startup', 'venture'
]

EXCLUDED_PATH_KEYWORDS = [
    '/auth', '/login', '/logout', '/signup', '/register',
    '/subscribe', '/subscription', '/account', '/profile',
    '/search', '/cart', '/checkout', '/privacy', '/terms', '/ethics-statement'
]

def is_valid_tech_url(url):
    """Kiểm tra URL có nằm trong chuyên mục bị cấm hay không."""
    url_lower = url.lower()
    for excluded in EXCLUDED_PATH_KEYWORDS:
        if excluded in url_lower:
            return False
    return True

def is_tech_related(url, title, content):
    """Kiểm tra URL, tiêu đề hoặc nội dung có chứa từ khóa công nghệ hay không."""
    text_to_check = f"{url} {title} {content}".lower()
    matches = sum(1 for kw in TECH_KEYWORDS if kw in text_to_check)
    return matches >= 1

def extract_page_data(html_content):
    soup = BeautifulSoup(html_content, "html.parser")
    title = soup.title.get_text(strip=True) if soup.title else "No Title"

    # Noise Removal: loại bỏ script, style, nav, footer, header thừa
    for tag in soup(["script", "style", "noscript", "nav", "footer", "aside"]):
        tag.decompose()

    content = soup.get_text(separator=" ", strip=True)
    return title, content, soup

def extract_and_filter_links(soup, base_url, allowed_domains):
    valid_links = []
    for tag in soup.find_all("a", href=True):
        href = tag["href"].strip()
        if href.startswith(('mailto:', 'javascript:', 'tel:', '#')):
            continue

        full_url = urljoin(base_url, href)
        parsed = urlparse(full_url)

        # Lọc giao thức và domain
        if parsed.scheme not in ('http', 'https'):
            continue
        if parsed.netloc.lower() not in allowed_domains:
            continue
            
        # Lọc đuôi file tĩnh
        if any(parsed.path.lower().endswith(ext) for ext in IGNORED_EXTENSIONS):
            continue

        # Kiểm tra đường dẫn có chứa chuyên mục bị cấm hay không
        if not is_valid_tech_url(full_url):
            continue

        clean_url = f"{parsed.scheme}://{parsed.netloc}{parsed.path}".rstrip('/')
        if not clean_url:
            clean_url = f"{parsed.scheme}://{parsed.netloc}/"
        valid_links.append(clean_url)
        
    return valid_links

print("Đã thiết lập Parser hoàn chỉnh.")
# Out:
# Đã thiết lập Parser hoàn chỉnh.

# %%
# Task 3 & 9: Thực thi Crawler và hiển thị thống kê
crawled_count = 0
failed_requests = 0
status_code_stats = {}
depth_stats = {d: 0 for d in range(MAX_DEPTH + 1)}

frontier.add_url(SEED_URL, depth=0)

print("=== BẮT ĐẦU CRAWL ===")
while not frontier.is_empty() and crawled_count < MAX_PAGES:
    current_url, current_depth = frontier.get_next()
    start_time = time.time()

    try:
        response = requests.get(current_url, headers=HEADERS, timeout=REQUEST_TIMEOUT)
        elapsed = time.time() - start_time
        status_code = response.status_code
    except requests.RequestException as e:
        failed_requests += 1
        print(f"[Error] {current_url}: {e}")
        continue

    status_code_stats[status_code] = status_code_stats.get(status_code, 0) + 1

    if "text/html" not in response.headers.get("Content-Type", ""):
        continue

    if status_code == 200:
        response.encoding = "utf-8"
        title, content, soup = extract_page_data(response.text)

        # 1. Kiểm tra exact duplicate
        if detector.is_duplicate(content):
            print(f"[Duplicate Content Skip] {current_url}")
            continue

        # 2. Kiểm tra ngữ nghĩa Tech TRƯỚC KHI lưu DB & bóc tách link
        if not is_tech_related(current_url, title, content):
            print(f"[Bỏ qua - Không liên quan Tech] {current_url}")
            continue

        # 3. Tăng biến đếm và ghi nhận dữ liệu hợp lệ
        crawled_count += 1
        depth_stats[current_depth] = depth_stats.get(current_depth, 0) + 1
        domain = urlparse(current_url).netloc
        crawled_at = datetime.now().isoformat()

        # 4. Lưu SQLite
        db.insert_page(current_url, domain, title, content, current_depth, status_code, crawled_at)

        # 5. Trích xuất và nạp link con vào Frontier
        links = extract_and_filter_links(soup, current_url, ALLOWED_DOMAINS)
        for link in links:
            db.insert_link(current_url, link)
            frontier.add_url(link, depth=current_depth + 1)

        print(f"[{crawled_count:03d}] Depth: {current_depth} | Status: {status_code} | Links: {len(links)} | Time: {elapsed:.2f}s | {current_url}")
    else:
        failed_requests += 1

    time.sleep(CRAWL_DELAY)

# In tổng kết
print("\n" + "=" * 25 + " CRAWLING SUMMARY " + "=" * 25)
print(f"Website                : {SEED_URL}")
print(f"Pages Crawled          : {crawled_count}")
print(f"Unique URLs Discovered : {frontier.discovered_count}")
print(f"Skipped URLs           : {frontier.skipped_count}")
print(f"Failed Requests        : {failed_requests}")
for d in range(MAX_DEPTH + 1):
    print(f"  - Depth {d}: {depth_stats.get(d, 0)} pages")
for code, cnt in sorted(status_code_stats.items()):
    print(f"  - HTTP {code}: {cnt}")
print("=" * 68)
# Out:
# === BẮT ĐẦU CRAWL ===
# [001] Depth: 0 | Status: 200 | Links: 202 | Time: 1.34s | https://techcrunch.com/
# [002] Depth: 1 | Status: 200 | Links: 53 | Time: 0.94s | https://techcrunch.com/events/techcrunch-disrupt
# [Duplicate Content Skip] https://techcrunch.com
# [003] Depth: 1 | Status: 200 | Links: 90 | Time: 1.07s | https://techcrunch.com/latest
# [004] Depth: 1 | Status: 200 | Links: 109 | Time: 1.66s | https://techcrunch.com/category/artificial-intelligence
# [005] Depth: 1 | Status: 200 | Links: 106 | Time: 0.99s | https://techcrunch.com/tag/amazon
# [006] Depth: 1 | Status: 200 | Links: 121 | Time: 1.00s | https://techcrunch.com/category/apps
# [007] Depth: 1 | Status: 200 | Links: 111 | Time: 0.91s | https://techcrunch.com/category/biotech-health
# [008] Depth: 1 | Status: 200 | Links: 111 | Time: 1.02s | https://techcrunch.com/category/climate
# [009] Depth: 1 | Status: 200 | Links: 108 | Time: 1.09s | https://techcrunch.com/tag/cloud-computing
# [010] Depth: 1 | Status: 200 | Links: 108 | Time: 1.03s | https://techcrunch.com/category/commerce
# [011] Depth: 1 | Status: 200 | Links: 108 | Time: 1.06s | https://techcrunch.com/category/cryptocurrency
# [012] Depth: 1 | Status: 200 | Links: 110 | Time: 0.97s | https://techcrunch.com/category/enterprise
# [013] Depth: 1 | Status: 200 | Links: 108 | Time: 0.99s | https://techcrunch.com/tag/evs
# [014] Depth: 1 | Status: 200 | Links: 110 | Time: 0.94s | https://techcrunch.com/category/fintech
# [015] Depth: 1 | Status: 200 | Links: 107 | Time: 0.93s | https://techcrunch.com/category/fundraising
# [016] Depth: 1 | Status: 200 | Links: 112 | Time: 1.02s | https://techcrunch.com/category/gadgets
# [017] Depth: 1 | Status: 200 | Links: 105 | Time: 0.95s | https://techcrunch.com/category/gaming
# [018] Depth: 1 | Status: 200 | Links: 107 | Time: 1.00s | https://techcrunch.com/tag/google
# [019] Depth: 1 | Status: 200 | Links: 109 | Time: 1.07s | https://techcrunch.com/category/government-policy
# [020] Depth: 1 | Status: 200 | Links: 109 | Time: 0.90s | https://techcrunch.com/category/hardware
# [021] Depth: 1 | Status: 200 | Links: 109 | Time: 0.88s | https://techcrunch.com/tag/instagram
# [022] Depth: 1 | Status: 200 | Links: 103 | Time: 1.03s | https://techcrunch.com/tag/layoffs
# [023] Depth: 1 | Status: 200 | Links: 102 | Time: 0.99s | https://techcrunch.com/category/media-entertainment
# [024] Depth: 1 | Status: 200 | Links: 107 | Time: 1.07s | https://techcrunch.com/tag/meta
# [025] Depth: 1 | Status: 200 | Links: 103 | Time: 1.05s | https://techcrunch.com/tag/microsoft
# [026] Depth: 1 | Status: 200 | Links: 111 | Time: 0.88s | https://techcrunch.com/category/robotics
# [027] Depth: 1 | Status: 200 | Links: 105 | Time: 0.91s | https://techcrunch.com/category/security
# [028] Depth: 1 | Status: 200 | Links: 109 | Time: 0.91s | https://techcrunch.com/category/social
# [029] Depth: 1 | Status: 200 | Links: 108 | Time: 0.94s | https://techcrunch.com/category/space
# [030] Depth: 1 | Status: 200 | Links: 110 | Time: 0.34s | https://techcrunch.com/category/startups
# [031] Depth: 1 | Status: 200 | Links: 104 | Time: 0.95s | https://techcrunch.com/tag/tiktok
# [032] Depth: 1 | Status: 200 | Links: 105 | Time: 0.94s | https://techcrunch.com/category/transportation
# [033] Depth: 1 | Status: 200 | Links: 111 | Time: 0.87s | https://techcrunch.com/category/venture
# [034] Depth: 1 | Status: 200 | Links: 48 | Time: 0.89s | https://techcrunch.com/about-techcrunch
# [035] Depth: 1 | Status: 200 | Links: 62 | Time: 0.92s | https://techcrunch.com/events
# [036] Depth: 1 | Status: 200 | Links: 49 | Time: 1.02s | https://techcrunch.com/startup-battlefield
# [037] Depth: 1 | Status: 200 | Links: 53 | Time: 1.08s | https://techcrunch.com/newsletters
# [038] Depth: 1 | Status: 200 | Links: 47 | Time: 0.88s | https://techcrunch.com/podcasts
# [039] Depth: 1 | Status: 200 | Links: 88 | Time: 0.91s | https://techcrunch.com/video
# [040] Depth: 1 | Status: 200 | Links: 82 | Time: 0.96s | https://techcrunch.com/sponsored
#
# ========================= CRAWLING SUMMARY =========================
# Website                : https://techcrunch.com/
# Pages Crawled          : 40
# Unique URLs Discovered : 4021
# Skipped URLs           : 3226
# Failed Requests        : 0
#   - Depth 0: 1 pages
#   - Depth 1: 39 pages
#   - Depth 2: 0 pages
#   - Depth 3: 0 pages
#   - HTTP 200: 41
# ====================================================================

# %%
# Cell 8: Kiểm tra dữ liệu an toàn (tự động kết nối lại nếu đã đóng)
import sqlite3
import pandas as pd

# 1. Mở lại kết nối nếu db đã bị đóng
try:
    cursor = db.conn.cursor()
except (sqlite3.ProgrammingError, AttributeError):
    print("Kết nối đã bị đóng từ trước, đang kết nối lại...")
    db = Database(DB_PATH)
    cursor = db.conn.cursor()

# 2. Kiểm tra tổng số dòng trong 2 bảng
cursor.execute("SELECT COUNT(*) FROM pages")
total_pages = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM links")
total_links = cursor.fetchone()[0]

print(f"-> Tổng số trang trong bảng 'pages': {total_pages}")
print(f"-> Tổng số liên kết trong bảng 'links': {total_links}\n")

# 3. Hiển thị 5 trang vừa crawl được
if total_pages > 0:
    df_pages = pd.read_sql_query("SELECT id, domain, url, title, depth, status_code FROM pages LIMIT 5", db.conn)
    display(df_pages)
else:
    print("⚠️ Cảnh báo: Bảng 'pages' đang RỖNG. Hãy chạy lại Cell 7 để crawl dữ liệu!")

# 4. Đóng kết nối khi hoàn thành
db.close()
print("Đã đóng kết nối cơ sở dữ liệu an toàn.")
# Out:
# -> Tổng số trang trong bảng 'pages': 42
# -> Tổng số liên kết trong bảng 'links': 9406
#    id          domain                                                url  \
# 0   1  techcrunch.com                            https://techcrunch.com/
# 1   2  techcrunch.com   https://techcrunch.com/events/techcrunch-disrupt
# 2   3  techcrunch.com  https://techcrunch.com/events/techcrunch-disru...
# 3   4  techcrunch.com                      https://techcrunch.com/latest
# 4   5  techcrunch.com  https://techcrunch.com/category/artificial-int...
#
#                                             title  depth  status_code
# 0        TechCrunch | Startup and Technology News      0          200
# 1            TechCrunch Disrupt 2026 | TechCrunch      1          200
# 2  Tickets - TechCrunch Disrupt 2026 | TechCrunch      1          200
# 3                        Latest News | TechCrunch      1          200
# 4  AI News & Artificial Intelligence | TechCrunch      1          200
# Đã đóng kết nối cơ sở dữ liệu an toàn.
