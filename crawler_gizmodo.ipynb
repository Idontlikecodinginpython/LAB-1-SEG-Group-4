# %%
# Task 1: Cài đặt và nạp các thư viện cần thiết
# Task 1: Cài đặt thư viện bắt buộc
# !pip install requests beautifulsoup4
import os
import time
import hashlib
import sqlite3
import requests
from datetime import datetime
from collections import deque
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup

print("Import thư viện chuẩn thành công!")
print("Import thư viện thành công!")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (4.16.0)
# Import thư viện chuẩn thành công!
# Import thư viện thành công!

# %%
# Task 1: Cấu hình tham số dành riêng cho TechCrunch
TOPIC = "Technology"
SEED_URL = "https://gizmodo.com/"
ALLOWED_DOMAINS = ["gizmodo.com", "www.gizmodo.com"]

MAX_DEPTH = 3
MAX_PAGES = 40            # Giới hạn 30-40 trang cho mỗi notebook
REQUEST_TIMEOUT = 10      # Giây
CRAWL_DELAY = 1.0         # Giây (Crawl Politeness)
DB_PATH = "data/gizmodo.db"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

print("=== CRAWLER CONFIGURATION ===")
print(f"Topic          : {TOPIC}")
print(f"Seed URL       : {SEED_URL}")
print(f"Allowed Domains: {ALLOWED_DOMAINS}")
print(f"Max Depth      : {MAX_DEPTH} | Max Pages: {MAX_PAGES}")
print(f"Crawl Delay    : {CRAWL_DELAY}s")
# Out:
# === CRAWLER CONFIGURATION ===
# Topic          : Technology
# Seed URL       : https://gizmodo.com/
# Allowed Domains: ['gizmodo.com', 'www.gizmodo.com']
# Max Depth      : 3 | Max Pages: 40
# Crawl Delay    : 1.0s

# %%
# Task 2, 6, 7: URL Frontier sử dụng deque (BFS) và set visited
class URLFrontier:
    def __init__(self, max_depth=3):
        self.queue = deque()
        self.visited = set()
        self.max_depth = max_depth
        self.discovered_count = 0
        self.skipped_count = 0

    def add_url(self, url, depth):
        self.discovered_count += 1
        if depth > self.max_depth or url in self.visited:
            self.skipped_count += 1
            return False
        self.visited.add(url)
        self.queue.append((url, depth))
        return True

    def get_next(self):
        return self.queue.popleft() if self.queue else None

    def is_empty(self):
        return len(self.queue) == 0

frontier = URLFrontier(max_depth=MAX_DEPTH)
print("Đã khởi tạo URL Frontier.")
# Out:
# Đã khởi tạo URL Frontier.

# %%
# Duplicate Detection: Kiểm tra exact duplicate nội dung bằng băm SHA-256
class DuplicateDetector:
    def __init__(self):
        self.fingerprints = set()

    def is_duplicate(self, text_content):
        if not text_content:
            return True
        fp = hashlib.sha256(text_content.strip().encode("utf-8")).hexdigest()
        if fp in self.fingerprints:
            return True
        self.fingerprints.add(fp)
        return False

detector = DuplicateDetector()
print("Đã khởi tạo Duplicate Detector.")
# Out:
# Đã khởi tạo Duplicate Detector.

# %%
# Task 8: Thiết lập SQLite lưu trữ bảng 'pages' và 'links'
class Database:
    def __init__(self, db_path):
        os.makedirs(os.path.dirname(db_path), exist_ok=True)
        self.conn = sqlite3.connect(db_path)
        self.create_tables()

    def create_tables(self):
        cursor = self.conn.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS pages (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                url TEXT UNIQUE,
                domain TEXT,
                title TEXT,
                content TEXT,
                depth INTEGER,
                status_code INTEGER,
                crawled_at TEXT
            )
        ''')
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS links (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                source_url TEXT,
                target_url TEXT
            )
        ''')
        self.conn.commit()

    def insert_page(self, url, domain, title, content, depth, status_code, crawled_at):
        cursor = self.conn.cursor()
        cursor.execute('''
            INSERT OR IGNORE INTO pages (url, domain, title, content, depth, status_code, crawled_at)
            VALUES (?, ?, ?, ?, ?, ?, ?)
        ''', (url, domain, title, content, depth, status_code, crawled_at))
        self.conn.commit()

    def insert_link(self, source_url, target_url):
        cursor = self.conn.cursor()
        cursor.execute('''
            INSERT INTO links (source_url, target_url)
            VALUES (?, ?)
        ''', (source_url, target_url))
        self.conn.commit()

    def close(self):
        self.conn.close()

db = Database(DB_PATH)
print("Đã kết nối SQLite Database.")
# Out:
# Đã kết nối SQLite Database.

# %%
# Task 4 & Task 5: Bóc tách text, khử nhiễu (Noise Removal) và lọc URL
IGNORED_EXTENSIONS = (
    '.jpg', '.jpeg', '.png', '.gif', '.svg', '.webp', '.ico',
    '.css', '.js', '.zip', '.tar', '.gz', '.pdf', '.mp4', '.mp3'
)

TECH_KEYWORDS = [
    'tech', 'technology', 'ai', 'artificial intelligence', 'software',
    'hardware', 'app', 'mobile', 'apple', 'google', 'microsoft', 'nvidia',
    'cybersecurity', 'gadget', 'robotics', 'cloud', 'data', 'crypto'
]

EXCLUDED_PATH_KEYWORDS = [
    '/entertainment', '/culture', '/lifestyle', '/film',
    '/tv', '/podcasts', '/review-books', '/politics','/auth', '/login', '/logout', '/signup', '/register',
    '/subscribe', '/subscription', '/account', '/profile',
    '/search', '/cart', '/checkout', '/privacy', '/terms'
]

def is_valid_tech_url(url):
    """Kiểm tra URL có nằm trong chuyên mục bị cấm hay không."""
    url_lower = url.lower()
    for excluded in EXCLUDED_PATH_KEYWORDS:
        if excluded in url_lower:
            return False
    return True

def is_tech_related(url, title, content):
    """Kiểm tra URL, tiêu đề hoặc nội dung có chứa từ khóa công nghệ hay không."""
    text_to_check = f"{url} {title} {content}".lower()
    matches = sum(1 for kw in TECH_KEYWORDS if kw in text_to_check)
    return matches >= 1

def extract_page_data(html_content):
    soup = BeautifulSoup(html_content, "html.parser")
    title = soup.title.get_text(strip=True) if soup.title else "No Title"

    # Noise Removal: loại bỏ script, style, nav, footer, header thừa
    for tag in soup(["script", "style", "noscript", "nav", "footer", "aside"]):
        tag.decompose()

    content = soup.get_text(separator=" ", strip=True)
    return title, content, soup

def extract_and_filter_links(soup, base_url, allowed_domains):
    valid_links = []
    for tag in soup.find_all("a", href=True):
        href = tag["href"].strip()
        if href.startswith(('mailto:', 'javascript:', 'tel:', '#')):
            continue

        full_url = urljoin(base_url, href)
        parsed = urlparse(full_url)

        # Lọc giao thức và domain
        if parsed.scheme not in ('http', 'https'):
            continue
        if parsed.netloc.lower() not in allowed_domains:
            continue

        # Lọc đuôi file tĩnh
        if any(parsed.path.lower().endswith(ext) for ext in IGNORED_EXTENSIONS):
            continue

        # ĐÃ SỬA: Kiểm tra đường dẫn có chứa chuyên mục bị cấm hay không
        if not is_valid_tech_url(full_url):
            continue

        clean_url = f"{parsed.scheme}://{parsed.netloc}{parsed.path}".rstrip('/')
        if not clean_url:
            clean_url = f"{parsed.scheme}://{parsed.netloc}/"
        valid_links.append(clean_url)

    return valid_links

print("Đã thiết lập Parser hoàn chỉnh.")
# Out:
# Đã thiết lập Parser hoàn chỉnh.

# %%
# Task 3 & 9: Thực thi Crawler và hiển thị thống kê
crawled_count = 0
failed_requests = 0
status_code_stats = {}
depth_stats = {d: 0 for d in range(MAX_DEPTH + 1)}

# Thêm Seed URL vào frontier
frontier.add_url(SEED_URL, depth=0)

print("=== BẮT ĐẦU CRAWL ===")
while not frontier.is_empty() and crawled_count < MAX_PAGES:
    current_url, current_depth = frontier.get_next()
    start_time = time.time()

    try:
        response = requests.get(current_url, headers=HEADERS, timeout=REQUEST_TIMEOUT)
        elapsed = time.time() - start_time
        status_code = response.status_code
    except requests.RequestException as e:
        failed_requests += 1
        print(f"[Error] {current_url}: {e}")
        continue

    status_code_stats[status_code] = status_code_stats.get(status_code, 0) + 1

    if "text/html" not in response.headers.get("Content-Type", ""):
        continue

    if status_code == 200:
        response.encoding = "utf-8"
        title, content, soup = extract_page_data(response.text)

        # 1. Kiểm tra exact duplicate
        if detector.is_duplicate(content):
            print(f"[Duplicate Content Skip] {current_url}")
            continue

        # 2. ĐÃ SỬA: Kiểm tra ngữ nghĩa Tech TRƯỚC KHI lưu DB & bóc tách link
        if not is_tech_related(current_url, title, content):
            print(f"[Bỏ qua - Không liên quan Tech] {current_url}")
            continue

        # 3. Tăng biến đếm và ghi nhận dữ liệu hợp lệ
        crawled_count += 1
        depth_stats[current_depth] = depth_stats.get(current_depth, 0) + 1
        domain = urlparse(current_url).netloc
        crawled_at = datetime.now().isoformat()

        # 4. Lưu SQLite
        db.insert_page(current_url, domain, title, content, current_depth, status_code, crawled_at)

        # 5. Trích xuất và nạp link con vào Frontier
        links = extract_and_filter_links(soup, current_url, ALLOWED_DOMAINS)
        for link in links:
            db.insert_link(current_url, link)
            frontier.add_url(link, depth=current_depth + 1)

        print(f"[{crawled_count:03d}] Depth: {current_depth} | Status: {status_code} | Links: {len(links)} | Time: {elapsed:.2f}s | {current_url}")
    else:
        failed_requests += 1

    time.sleep(CRAWL_DELAY)

# In tổng kết
print("\n" + "=" * 25 + " CRAWLING SUMMARY " + "=" * 25)
print(f"Website                : {SEED_URL}")
print(f"Pages Crawled          : {crawled_count}")
print(f"Unique URLs Discovered : {frontier.discovered_count}")
print(f"Skipped URLs           : {frontier.skipped_count}")
print(f"Failed Requests        : {failed_requests}")
for d in range(MAX_DEPTH + 1):
    print(f"  - Depth {d}: {depth_stats.get(d, 0)} pages")
for code, cnt in sorted(status_code_stats.items()):
    print(f"  - HTTP {code}: {cnt}")
print("=" * 68)
# Out:
# === BẮT ĐẦU CRAWL ===
# [001] Depth: 0 | Status: 200 | Links: 217 | Time: 0.46s | https://gizmodo.com/
# [002] Depth: 1 | Status: 200 | Links: 96 | Time: 0.43s | https://gizmodo.com/thing-2-0-this-creepy-cute-robot-walks-on-its-fingers-2000815604
# [003] Depth: 1 | Status: 200 | Links: 98 | Time: 0.61s | https://gizmodo.com/big-banks-say-theyre-uneasy-about-people-shopping-via-ai-agents-2000815443
# [004] Depth: 1 | Status: 200 | Links: 103 | Time: 0.43s | https://gizmodo.com/george-lucas-was-indeed-planning-to-do-more-star-wars-movies-2000815652
# [005] Depth: 1 | Status: 200 | Links: 74 | Time: 0.37s | https://gizmodo.com/inius-10000mah-magsafe-power-bank-makes-a-perfect-iphone-18-pro-companion-for-a-charging-boost-2000812122
# [006] Depth: 1 | Status: 200 | Links: 96 | Time: 0.44s | https://gizmodo.com/ai-contractors-shouldnt-use-ai-to-evaluate-ai-model-says-ai-company-2000815621
# [007] Depth: 1 | Status: 200 | Links: 99 | Time: 0.43s | https://gizmodo.com/nearly-1-in-6-kids-on-glp-1s-developed-this-problem-within-a-year-2000815568
# [008] Depth: 1 | Status: 200 | Links: 95 | Time: 0.35s | https://gizmodo.com/andreessen-horowitz-wants-teens-to-skip-college-for-its-new-academy-instead-2000815660
# [009] Depth: 1 | Status: 200 | Links: 104 | Time: 0.43s | https://gizmodo.com/openai-releases-new-gpt-6-sol-and-luna-models-sells-them-as-mini-astras-2000815731
# [010] Depth: 1 | Status: 200 | Links: 93 | Time: 0.43s | https://gizmodo.com/new-adtech-from-microsoft-would-interrupt-your-game-at-promoted-content-trigger-events-2000815772
# [011] Depth: 1 | Status: 200 | Links: 100 | Time: 0.20s | https://gizmodo.com/scott-bessent-could-soon-be-trumps-ai-czar-report-says-2000815770
# [012] Depth: 1 | Status: 200 | Links: 143 | Time: 0.43s | https://gizmodo.com/tech/artificial-intelligence
# [013] Depth: 1 | Status: 200 | Links: 101 | Time: 0.43s | https://gizmodo.com/ten-days-after-ceo-calls-for-a-slowdown-anthropic-is-back-with-another-ai-model-2000815586
# [014] Depth: 1 | Status: 200 | Links: 98 | Time: 0.44s | https://gizmodo.com/mathematics-just-got-its-first-taste-of-the-ai-job-pocalypse-2000812872
# [015] Depth: 1 | Status: 200 | Links: 100 | Time: 0.41s | https://gizmodo.com/openai-calls-for-us-to-lead-global-ai-standards-will-china-be-okay-with-that-2000815022
# [016] Depth: 1 | Status: 200 | Links: 101 | Time: 0.36s | https://gizmodo.com/meta-just-patched-a-major-zero-day-vulnerability-in-its-muse-ai-assistant-2000815429
# [017] Depth: 1 | Status: 200 | Links: 111 | Time: 0.30s | https://gizmodo.com/polymarket-bug-reportedly-let-identity-thieves-into-existing-accounts-2000814520
# [018] Depth: 1 | Status: 200 | Links: 102 | Time: 0.37s | https://gizmodo.com/fbi-warns-ice-agents-not-to-trust-any-woman-willing-to-date-them-2000814283
# [019] Depth: 1 | Status: 200 | Links: 99 | Time: 0.36s | https://gizmodo.com/josh-hawley-wants-to-haul-flock-ceos-ass-in-front-of-the-senate-next-week-2000814073
# [020] Depth: 1 | Status: 200 | Links: 107 | Time: 0.36s | https://gizmodo.com/elon-musk-reportedly-seeking-customer-data-from-dead-startups-to-train-ai-2000813451
# [021] Depth: 1 | Status: 200 | Links: 101 | Time: 0.41s | https://gizmodo.com/mastercard-is-giving-ai-agents-virtual-cards-to-handle-your-shopping-2000813310
# [022] Depth: 1 | Status: 200 | Links: 143 | Time: 0.44s | https://gizmodo.com/tech/cryptocurrencies
# [023] Depth: 1 | Status: 200 | Links: 97 | Time: 0.35s | https://gizmodo.com/feds-reportedly-investigating-crypto-titan-binance-over-iran-sanctions-2000815127
# [024] Depth: 1 | Status: 200 | Links: 108 | Time: 0.44s | https://gizmodo.com/mr-robots-ecoin-comes-to-life-via-wall-streets-new-blockchain-2000813297
# [025] Depth: 1 | Status: 200 | Links: 106 | Time: 0.43s | https://gizmodo.com/the-crypto-industry-wasnt-able-to-buy-congress-after-all-2000812603
# [026] Depth: 1 | Status: 200 | Links: 103 | Time: 0.44s | https://gizmodo.com/bitcoins-network-hashrate-is-50-below-trend-as-miners-shift-to-ai-2000811882
# [027] Depth: 1 | Status: 200 | Links: 109 | Time: 0.46s | https://gizmodo.com/cryptos-latest-stablecoin-innovation-chargebacks-2000811401
# [028] Depth: 1 | Status: 200 | Links: 100 | Time: 0.43s | https://gizmodo.com/white-hat-liquid-network-crypto-hackers-are-now-grandstanding-and-demanding-a-10-bounty-2000809413
# [029] Depth: 1 | Status: 200 | Links: 105 | Time: 0.42s | https://gizmodo.com/hunter-bidens-crypto-memecoin-launch-went-even-worse-than-predicted-2000809266
# [030] Depth: 1 | Status: 200 | Links: 143 | Time: 0.43s | https://gizmodo.com/tech/transportation
# [031] Depth: 1 | Status: 200 | Links: 95 | Time: 0.43s | https://gizmodo.com/trumps-proposed-diesel-export-ban-could-backfire-enormously-2000815624
# [032] Depth: 1 | Status: 200 | Links: 96 | Time: 0.43s | https://gizmodo.com/autonomous-plane-becomes-the-first-to-fly-coast-to-coast-on-its-own-2000814879
# [033] Depth: 1 | Status: 200 | Links: 97 | Time: 0.20s | https://gizmodo.com/are-truckers-really-going-on-strike-oct-1-2000813490
# [034] Depth: 1 | Status: 200 | Links: 97 | Time: 0.42s | https://gizmodo.com/nhtsa-orders-tesla-to-prove-its-cybercab-meets-federal-safety-standards-2000812821
# [035] Depth: 1 | Status: 200 | Links: 97 | Time: 0.43s | https://gizmodo.com/you-really-should-book-your-holiday-flights-right-now-2000811364
# [036] Depth: 1 | Status: 200 | Links: 99 | Time: 0.46s | https://gizmodo.com/say-hello-to-6-diesel-2000810340
# [037] Depth: 1 | Status: 200 | Links: 172 | Time: 0.44s | https://gizmodo.com/reviews
# [038] Depth: 1 | Status: 200 | Links: 113 | Time: 0.43s | https://gizmodo.com/iphone-18-pro-and-18-pro-max-review-apple-is-just-flexing-now-2000812130
# [039] Depth: 1 | Status: 200 | Links: 103 | Time: 0.44s | https://gizmodo.com/airpods-5-review-a-ridiculously-great-value-for-anc-wireless-earbuds-2000811531
# [040] Depth: 1 | Status: 200 | Links: 116 | Time: 0.43s | https://gizmodo.com/steam-frame-review-valve-shows-us-vr-was-always-meant-to-be-a-toy-2000811281
#
# ========================= CRAWLING SUMMARY =========================
# Website                : https://gizmodo.com/
# Pages Crawled          : 40
# Unique URLs Discovered : 4338
# Skipped URLs           : 3811
# Failed Requests        : 0
#   - Depth 0: 1 pages
#   - Depth 1: 39 pages
#   - Depth 2: 0 pages
#   - Depth 3: 0 pages
#   - HTTP 200: 40
# ====================================================================

# %%
# Cell 8: Kiểm tra dữ liệu an toàn (tự động kết nối lại nếu đã đóng)
import sqlite3
import pandas as pd

# 1. Mở lại kết nối nếu db đã bị đóng
try:
    cursor = db.conn.cursor()
except (sqlite3.ProgrammingError, AttributeError):
    print("Kết nối đã bị đóng từ trước, đang kết nối lại...")
    db = Database(DB_PATH)
    cursor = db.conn.cursor()

# 2. Kiểm tra tổng số dòng trong 2 bảng
cursor.execute("SELECT COUNT(*) FROM pages")
total_pages = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM links")
total_links = cursor.fetchone()[0]

print(f"-> Tổng số trang trong bảng 'pages': {total_pages}")
print(f"-> Tổng số liên kết trong bảng 'links': {total_links}\n")

# 3. Hiển thị 5 trang vừa crawl được
if total_pages > 0:
    df_pages = pd.read_sql_query("SELECT id, domain, url, title, depth, status_code FROM pages LIMIT 5", db.conn)
    display(df_pages)
else:
    print("⚠️ Cảnh báo: Bảng 'pages' đang RỖNG. Hãy chạy lại Cell 7 để crawl dữ liệu!")

# 4. Đóng kết nối khi hoàn thành
db.close()
print("Đã đóng kết nối cơ sở dữ liệu an toàn.")
# Out:
# -> Tổng số trang trong bảng 'pages': 40
# -> Tổng số liên kết trong bảng 'links': 4337
#    id       domain                                                url  \
# 0   1  gizmodo.com                               https://gizmodo.com/
# 1   2  gizmodo.com  https://gizmodo.com/thing-2-0-this-creepy-cute...
# 2   3  gizmodo.com  https://gizmodo.com/big-banks-say-theyre-uneas...
# 3   4  gizmodo.com  https://gizmodo.com/george-lucas-was-indeed-pl...
# 4   5  gizmodo.com  https://gizmodo.com/inius-10000mah-magsafe-pow...
#
#                                                title  depth  status_code
# 0                       Gizmodo | The Future Is Here      0          200
# 1  Thing 2.0? This Creepy-Cute Robot Walks on Its...      1          200
# 2  Big Banks Say They're Uneasy About People Shop...      1          200
# 3  George Lucas Was Indeed Planning to Do More 'S...      1          200
# 4  INIU’s 10,000mAh MagSafe Power Bank Makes a Pe...      1          200
# Đã đóng kết nối cơ sở dữ liệu an toàn.
